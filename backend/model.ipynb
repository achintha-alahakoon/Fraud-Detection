# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.0.2

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: pandas in c:\users\dell\miniconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\miniconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\miniconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\dell\miniconda3\lib\site-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\miniconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting matplotlib
#   Downloading matplotlib-3.9.4-cp39-cp39-win_amd64.whl (7.8 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib) (25.0)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-win_amd64.whl (55 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.23 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib) (2.0.2)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-win_amd64.whl (211 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.59.0-cp39-cp39-win_amd64.whl (1.5 MB)
# Collecting pillow>=8
#   Downloading pillow-11.3.0-cp39-cp39-win_amd64.whl (7.0 MB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dell\miniconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.59.0 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 pillow-11.3.0 pyparsing-3.2.3
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dell\miniconda3\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dell\miniconda3\lib\site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\dell\miniconda3\lib\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: pillow>=8 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dell\miniconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")

# %%
df = pd.read_csv('../multipleChoiceResponses.csv')

# %%
df.head()
# Out:
#   Time from Start to Finish (seconds)                                      Q1  \
# 0               Duration (in seconds)  What is your gender? - Selected Choice
# 1                                 710                                  Female
# 2                                 434                                    Male
# 3                                 718                                  Female
# 4                                 621                                    Male
#
#                                        Q1_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                             Q2                                         Q3  \
# 0  What is your age (# years)?  In which country do you currently reside?
# 1                        45-49                   United States of America
# 2                        30-34                                  Indonesia
# 3                        30-34                   United States of America
# 4                        35-39                   United States of America
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Doctoral degree
# 2                                  Bachelor’s degree
# 3                                    Master’s degree
# 4                                    Master’s degree
#
#                                                   Q5  \
# 0  Which best describes your undergraduate major?...
# 1                                              Other
# 2                 Engineering (non-computer focused)
# 3      Computer science (software engineering, etc.)
# 4  Social sciences (anthropology, psychology, soc...
#
#                                                   Q6  \
# 0  Select the title most similar to your current ...
# 1                                         Consultant
# 2                                              Other
# 3                                     Data Scientist
# 4                                       Not employed
#
#                                        Q6_OTHER_TEXT  \
# 0  Select the title most similar to your current ...
# 1                                                 -1
# 2                                                  0
# 3                                                 -1
# 4                                                 -1
#
#                                                   Q7  ...  \
# 0  In what industry is your current employer/cont...  ...
# 1                                              Other  ...
# 2                          Manufacturing/Fabrication  ...
# 3                                     I am a student  ...
# 4                                                NaN  ...
#
#                                       Q49_OTHER_TEXT  \
# 0  What tools and methods do you use to make your...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                                           Q50_Part_1  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q50_Part_2  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                 Too time-consuming
# 4                                                NaN
#
#                                           Q50_Part_3  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4              Requires too much technical knowledge
#
#                                           Q50_Part_4  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q50_Part_5  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4             Not enough incentives to share my work
#
#                                           Q50_Part_6  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q50_Part_7  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                           Q50_Part_8  \
# 0  What barriers prevent you from making your wor...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       Q50_OTHER_TEXT
# 0  What barriers prevent you from making your wor...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
# [5 rows x 395 columns]

# %%
df.shape
# Out:
# (23860, 395)

# %%
df.duplicated().sum()
# Out:
# np.int64(12)

# %%
df = df.drop_duplicates()

# %%
df = df.dropna(thresh=len(df)*0.6, axis=1)

# %%
missing_counts = df.isnull().sum()
missing_percentage = (missing_counts / len(df)) * 100
missing_counts[missing_counts > 0].sort_values(ascending=False)
# Out:
# Q41_Part_1             8911
# Q41_Part_3             8911
# Q41_Part_2             8911
# Q17                    8625
# Q16_Part_1             8136
# Q35_Part_1             8102
# Q35_Part_4             8102
# Q35_Part_3             8102
# Q35_Part_5             8102
# Q35_Part_6             8102
# Q35_Part_2             8102
# Q40                    7968
# Q34_Part_3             7910
# Q34_Part_6             7910
# Q34_Part_5             7910
# Q34_Part_2             7910
# Q34_Part_1             7910
# Q34_Part_4             7910
# Q39_Part_2             7868
# Q39_Part_1             7868
# Q26                    5367
# Q25                    5356
# Q24                    5314
# Q23                    5300
# Q18                    5191
# Q12_MULTIPLE_CHOICE    4649
# Q9                     3662
# Q10                    3178
# Q8                     2746
# Q7                     2163
# Q6                      948
# Q5                      901
# Q4                      413
# dtype: int64

# %%
df.dtypes.value_counts()
# Out:
# object    72
# Name: count, dtype: int64

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\dell\miniconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dell\miniconda3\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dell\miniconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\dell\miniconda3\lib\site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\miniconda3\lib\site-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.impute import SimpleImputer

# All columns are categorical
cat_imputer = SimpleImputer(strategy='most_frequent')
df[df.columns] = cat_imputer.fit_transform(df)

# %%
print("Remaining missing values:", df.isnull().sum().sum())
# Out:
# Remaining missing values: 0

# %%
df.shape
# Out:
# (23848, 72)

# %%
df.head()
# Out:
#   Time from Start to Finish (seconds)                                      Q1  \
# 0               Duration (in seconds)  What is your gender? - Selected Choice
# 1                                 710                                  Female
# 2                                 434                                    Male
# 3                                 718                                  Female
# 4                                 621                                    Male
#
#                                        Q1_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                             Q2                                         Q3  \
# 0  What is your age (# years)?  In which country do you currently reside?
# 1                        45-49                   United States of America
# 2                        30-34                                  Indonesia
# 3                        30-34                   United States of America
# 4                        35-39                   United States of America
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                                    Doctoral degree
# 2                                  Bachelor’s degree
# 3                                    Master’s degree
# 4                                    Master’s degree
#
#                                                   Q5  \
# 0  Which best describes your undergraduate major?...
# 1                                              Other
# 2                 Engineering (non-computer focused)
# 3      Computer science (software engineering, etc.)
# 4  Social sciences (anthropology, psychology, soc...
#
#                                                   Q6  \
# 0  Select the title most similar to your current ...
# 1                                         Consultant
# 2                                              Other
# 3                                     Data Scientist
# 4                                       Not employed
#
#                                        Q6_OTHER_TEXT  \
# 0  Select the title most similar to your current ...
# 1                                                 -1
# 2                                                  0
# 3                                                 -1
# 4                                                 -1
#
#                                                   Q7  ...  \
# 0  In what industry is your current employer/cont...  ...
# 1                                              Other  ...
# 2                          Manufacturing/Fabrication  ...
# 3                                     I am a student  ...
# 4                               Computers/Technology  ...
#
#                                       Q38_OTHER_TEXT  \
# 0  Who/what are your favorite media sources that ...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                                           Q39_Part_1  \
# 0  How do you perceive the quality of online lear...
# 1                                        Much better
# 2                                     Slightly worse
# 3                                     Slightly worse
# 4                                         Much worse
#
#                                           Q39_Part_2  \
# 0  How do you perceive the quality of online lear...
# 1                                         Much worse
# 2                          No opinion; I do not know
# 3                                    Slightly better
# 4                          No opinion; I do not know
#
#                                                  Q40  \
# 0  Which better demonstrates expertise in data sc...
# 1  Independent projects are equally important as ...
# 2  Independent projects are equally important as ...
# 3  Independent projects are equally important as ...
# 4  Independent projects are much more important t...
#
#                                           Q41_Part_1  \
# 0  How do you perceive the importance of the foll...
# 1                                     Very important
# 2                                     Very important
# 3                                     Very important
# 4                                     Very important
#
#                                           Q41_Part_2  \
# 0  How do you perceive the importance of the foll...
# 1                                     Very important
# 2                                     Very important
# 3                                     Very important
# 4                                     Very important
#
#                                           Q41_Part_3  \
# 0  How do you perceive the importance of the foll...
# 1                                     Very important
# 2                                     Very important
# 3                                     Very important
# 4                                     Very important
#
#                                       Q42_OTHER_TEXT  \
# 0  What metrics do you or your organization use t...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                                       Q49_OTHER_TEXT  \
# 0  What tools and methods do you use to make your...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
#                                       Q50_OTHER_TEXT
# 0  What barriers prevent you from making your wor...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# 4                                                 -1
#
# [5 rows x 72 columns]
